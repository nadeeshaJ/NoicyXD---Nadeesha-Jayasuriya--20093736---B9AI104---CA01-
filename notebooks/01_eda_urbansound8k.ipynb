# %% [markdown]
# # Step 1 — Dataset Acquisition & EDA
#
# **UrbanSound8K** (Stage 1) and **ESC-50 Animals** (Stage 2)
#
# Run the automated pipeline first:
# ```bash
# python scripts/run_step1_eda.py
# python scripts/generate_step1_report.py
# ```
#
# Outputs: `reports/figures/step1/`, `reports/step1/`, `data/splits/*/class_mapping.json`

# %%
import sys
from pathlib import Path

ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
sys.path.insert(0, str(ROOT))

import pandas as pd
from src.utils import load_config, project_path

cfg = load_config()
urban_meta = pd.read_csv(project_path(cfg["datasets"]["urbansound8k"]["metadata"]))
esc_meta = pd.read_csv(project_path(cfg["datasets"]["esc50_animals"]["metadata"]))

print("UrbanSound8K clips:", len(urban_meta))
print("ESC-50 Animals clips:", len(esc_meta))
urban_meta.head()

# %%
inventory = pd.read_csv(ROOT / "reports" / "step1" / "dataset_inventory.csv")
inventory
