# %% [markdown]
# # Step 4 — ESC-50 Transfer Learning & Cross-Domain Analysis
#
# ```bash
# python scripts/run_step4_esc50.py
# python scripts/generate_step4_report.py
# ```
#
# Report: `reports/step4/Step4_CrossDomain_Report.docx`

# %%
import pandas as pd
from pathlib import Path

ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
pd.read_csv(ROOT / "reports" / "step4" / "cross_domain_comparison.csv")

# %% [markdown]
# # Step 3 — Model Design & UrbanSound8K Training
#
# Three models: **Custom CNN**, **ResNet50**, **MobileNetV2**
#
# ```bash
# python scripts/run_step3_train.py
# python scripts/generate_step3_report.py
# ```
#
# Report: `reports/step3/Step3_Model_Training_Report.docx`

# %%
import pandas as pd
from pathlib import Path

ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
comparison = pd.read_csv(ROOT / "reports" / "step3" / "model_comparison_urbansound8k.csv")
comparison

# %%
import matplotlib.pyplot as plt

img = plt.imread(ROOT / "reports" / "figures" / "step3" / "model_comparison_urbansound8k.png")
plt.figure(figsize=(10, 4))
plt.imshow(img)
plt.axis("off")
plt.title("UrbanSound8K test set — model comparison (fold 10)")
plt.show()
