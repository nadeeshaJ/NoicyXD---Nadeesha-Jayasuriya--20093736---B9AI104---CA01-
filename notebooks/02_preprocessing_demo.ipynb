# %% [markdown]
# # Step 2 — Preprocessing Pipeline
#
# Converts audio clips to **224×224 RGB Mel-spectrogram PNG** images.
#
# ```bash
# python scripts/run_step2_preprocess.py
# python scripts/generate_step2_report.py
# ```
#
# Report: `reports/step2/Step2_Preprocessing_Report.docx`

# %%
import sys
from pathlib import Path
import pandas as pd
from PIL import Image
import matplotlib.pyplot as plt

ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
sys.path.insert(0, str(ROOT))

validation = pd.read_csv(ROOT / "reports" / "step2" / "preprocessing_validation.csv")
validation

# %%
fig_path = ROOT / "reports" / "figures" / "step2" / "preprocessing_examples_urbansound8k.png"
img = plt.imread(fig_path)
plt.figure(figsize=(12, 8))
plt.imshow(img)
plt.axis("off")
plt.title("Preprocessing examples: waveform → Mel-spec → RGB image")
plt.show()
